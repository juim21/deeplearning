# %%
import os
import pandas as pd
import numpy as np

# %%
DATASET_PATH = 'dataset/'

# %%
data_path = os.path.join(DATASET_PATH, 'cam_dataset_all.csv')
dataset = pd.read_csv(data_path)

# %%
dataset.shape
# Out:
# (32060, 144)

# %%
dataset.head()
# Out:
#           고객번호 인터넷결합여부 IPTV결합여무  SOP결합여부 PSTN결합여부  와이브로결합여부 모바일결합여부  PSTN회선수  \
# 0  87HL036LE93       Y        Y      NaN        Y       NaN       Y        1
# 1  8MYL79EHX9Z       Y        Y      NaN        Y       NaN       Y        2
# 2  7QLKZUQHXHJ       Y        Y      NaN        N       NaN       Y        0
# 3  BE1L6Y4H2NG       N        N      NaN        N       NaN       N        0
# 4  9KWL716JWKU       N        N      NaN        N       NaN       N        1
#
#    모바일회선수  SOIP회선수  ...  최근3개월데이터충전횟수  최근3개월패박사용횟수  스폰서할인유형 판매유형  사용유형  \
# 0       1        2  ...             0            0        _    _    일반
# 1       0        0  ...             0            0        _    _    일반
# 2       1        0  ...             1            0        _    _    일반
# 3       0        0  ...             0            0        _    _    일반
# 4       0        0  ...             0            0        _    _   주택용
#
#         납무방법    반응1       반응2   반응3           반응4
# 0  은행계좌 자동이체  SR불필요     SR미발행  혜택제공  지속사용(고객혜택제공)
# 1       신용카드  SR불필요     SR미발행  혜택제공  지속사용(고객혜택제공)
# 2       신용카드  SR불필요     SR미발행  혜택제공  지속사용(고객혜택제공)
# 3  은행계좌 자동이체  고객측사유  고객측사유_기타    KT            해지
# 4  은행계좌 자동이체  SR불필요     SR미발행  혜택제공  지속사용(고객혜택제공)
#
# [5 rows x 144 columns]

# %%
corr = dataset.corr()

# %%
corr
# Out:
#                    SOP결합여부  와이브로결합여부   PSTN회선수    모바일회선수   SOIP회선수    인터넷회선수  \
# SOP결합여부                NaN       NaN       NaN       NaN       NaN       NaN
# 와이브로결합여부               NaN       NaN       NaN       NaN       NaN       NaN
# PSTN회선수                NaN       NaN  1.000000 -0.055729  0.078458  0.239526
# 모바일회선수                 NaN       NaN -0.055729  1.000000  0.002298  0.091699
# SOIP회선수                NaN       NaN  0.078458  0.002298  1.000000  0.135615
# 인터넷회선수                 NaN       NaN  0.239526  0.091699  0.135615  1.000000
# IPTV회선수                NaN       NaN  0.003360  0.060414  0.032145  0.398207
# 와이브로회선수                NaN       NaN  0.010350  0.012115  0.019836  0.052924
# 모바일약정전여개월수             NaN       NaN  0.115212 -0.766169  0.015110 -0.051474
# 모바일해지후개월수              NaN       NaN -0.019799  0.424883 -0.019379  0.042964
# 나이                     NaN       NaN  0.133897 -0.157765  0.121564  0.076698
# 인터넷가입경과개월수             NaN       NaN  0.111260 -0.114287 -0.010849 -0.115273
# 인터넷만료기간개월수             NaN       NaN  0.021602 -0.064808 -0.035276 -0.287111
# 인터넷해지경과개월수             NaN       NaN -0.033601  0.022746 -0.002281  0.154149
# IPTV약정만료잔여개월수          NaN       NaN  0.110998 -0.114255 -0.006747 -0.114851
# IPTV_3개월_ARPU          NaN       NaN -0.012678  0.091891  0.009537  0.205724
# 모바일_3개월_ARPU           NaN       NaN -0.092042  0.731965 -0.017688  0.081455
# 인터넷_3개월_ARPU           NaN       NaN  0.120730  0.003364  0.036012  0.325053
# 모바일_6개월_ARPU           NaN       NaN -0.093851  0.735940 -0.017346  0.084220
# 인터넷_6개월_ARPU           NaN       NaN  0.192940  0.012568  0.088481  0.591725
# 최근3개월IPTV_사용시간         NaN       NaN -0.117720  0.027507 -0.052961 -0.046123
# 가입후경과개월수               NaN       NaN  0.059314 -0.053101  0.076429 -0.054635
# 결합약정만료잔여개월수            NaN       NaN  0.034125 -0.049898 -0.042425  0.089594
# 최근월PPV사용금액             NaN       NaN -0.035917  0.004306 -0.010037 -0.002352
# 약정잔여개월수                NaN       NaN  0.295092 -0.066972 -0.015978 -0.086801
# 전월PPV사용요금              NaN       NaN -0.037008  0.008323 -0.013629 -0.001895
# 최근3개월무료량초과개월수          NaN       NaN  0.017950 -0.024691  0.017758 -0.032188
# 3개월_ARPU               NaN       NaN -0.071523 -0.017149 -0.072277  0.055262
# 최근3개월무선데이터사용량          NaN       NaN  0.005854  0.031088  0.006821  0.013759
# 최근무선데이터사용량             NaN       NaN  0.005848  0.031076  0.006763  0.013777
# ...                    ...       ...       ...       ...       ...       ...
# 단말기잔여할부금액              NaN       NaN  0.000905  0.002365 -0.002499 -0.002072
# 데이터총제공량                NaN       NaN  0.005962  0.030804  0.007191  0.012542
# 말일데이터사용량               NaN       NaN  0.005848  0.031076  0.006763  0.013777
# 말일데이터소진율               NaN       NaN  0.005901  0.031140  0.007238  0.013531
# 평균3개월데이터소진율            NaN       NaN  0.005884  0.031123  0.007154  0.013614
# 타사모바일사용단말기수            NaN       NaN -0.001665 -0.030810 -0.011577  0.103286
# 타사추정만료단말기수             NaN       NaN  0.022123 -0.027612  0.000333  0.041324
# 최근3개월멤버쉽사용횟수           NaN       NaN -0.058296  0.251023  0.044464  0.072012
# 최근6개월멤버쉽사용횟수           NaN       NaN -0.055350  0.272883  0.044430  0.082083
# 최근1년멤버쉽사용횟수            NaN       NaN -0.055395  0.293979  0.047513  0.091043
# 최근3개월VIP횟수             NaN       NaN -0.031465  0.261805  0.031940  0.102999
# 최근6개월VIP초이스횟수          NaN       NaN -0.032407  0.266126  0.034234  0.110588
# 최근1년VIP초이스횟수           NaN       NaN       NaN       NaN       NaN       NaN
# 최근3개월더블할인횟수            NaN       NaN -0.050243  0.193718  0.004048  0.013620
# 최근6개월더블할인횟수            NaN       NaN -0.047039  0.206768  0.006708  0.012939
# 최근1년베이커리횟수             NaN       NaN -0.039623  0.216136 -0.003544  0.020361
# 최근3개월영화횟수              NaN       NaN       NaN       NaN       NaN       NaN
# 최근1년영화관람횟수             NaN       NaN -0.041725  0.250256  0.011242  0.091495
# 최근3개월외식횟수              NaN       NaN -0.025451  0.153772  0.025514  0.044454
# 최근1년외식횟수               NaN       NaN -0.043864  0.207762  0.012280  0.048780
# 최근3개월카페사용횟수            NaN       NaN       NaN       NaN       NaN       NaN
# 최근1년카페사용횟수             NaN       NaN -0.038492  0.174255  0.020174  0.036755
# 최근3개월편의점사용횟수           NaN       NaN -0.037063  0.146626 -0.004403  0.010118
# 최근1년편의점사용횟수            NaN       NaN -0.032537  0.177676 -0.006958  0.022504
# 최근1년그레이드컬처횟수           NaN       NaN -0.030337  0.042124 -0.004351  0.017123
# 최근1년그레이트페스티벌횟수         NaN       NaN -0.030479  0.029680 -0.008014  0.070176
# 최근3개월지니팩사용횟수           NaN       NaN -0.014293  0.045054 -0.012564  0.007051
# 최근3개월IPTV_VOD사용횟수      NaN       NaN -0.014202  0.083889  0.056976  0.067641
# 최근3개월데이터충전횟수           NaN       NaN -0.058230  0.117934 -0.014513 -0.013906
# 최근3개월패박사용횟수            NaN       NaN -0.023119  0.065811  0.014429 -0.010870
#
#                     IPTV회선수   와이브로회선수  모바일약정전여개월수  모바일해지후개월수  ...  \
# SOP결합여부                 NaN       NaN         NaN        NaN  ...
# 와이브로결합여부                NaN       NaN         NaN        NaN  ...
# PSTN회선수            0.003360  0.010350    0.115212  -0.019799  ...
# 모바일회선수             0.060414  0.012115   -0.766169   0.424883  ...
# SOIP회선수            0.032145  0.019836    0.015110  -0.019379  ...
# 인터넷회선수             0.398207  0.052924   -0.051474   0.042964  ...
# IPTV회선수            1.000000  0.004962   -0.058289   0.043910  ...
# 와이브로회선수            0.004962  1.000000   -0.015160  -0.004278  ...
# 모바일약정전여개월수        -0.058289 -0.015160    1.000000  -0.504280  ...
# 모바일해지후개월수          0.043910 -0.004278   -0.504280   1.000000  ...
# 나이                 0.070213 -0.007417    0.184276   0.074496  ...
# 인터넷가입경과개월수        -0.469797 -0.007831    0.140382  -0.020142  ...
# 인터넷만료기간개월수        -0.112117 -0.006347    0.062895  -0.003003  ...
# 인터넷해지경과개월수         0.063397  0.002716   -0.025529   0.020149  ...
# IPTV약정만료잔여개월수     -0.468378 -0.008040    0.141132  -0.019775  ...
# IPTV_3개월_ARPU      0.382395  0.003792   -0.075007   0.044143  ...
# 모바일_3개월_ARPU       0.055722  0.028385   -0.731987   0.342865  ...
# 인터넷_3개월_ARPU       0.123710  0.049332    0.015130   0.005373  ...
# 모바일_6개월_ARPU       0.055241  0.027261   -0.731272   0.334720  ...
# 인터넷_6개월_ARPU       0.213109  0.094052    0.037119   0.005959  ...
# 최근3개월IPTV_사용시간     0.118217 -0.005946   -0.042427   0.008244  ...
# 가입후경과개월수          -0.035657  0.005189    0.041878  -0.107816  ...
# 결합약정만료잔여개월수       -0.051293  0.016509    0.080354  -0.011727  ...
# 최근월PPV사용금액         0.043456 -0.004306    0.002863   0.002259  ...
# 약정잔여개월수           -0.098338  0.000745    0.072816  -0.011625  ...
# 전월PPV사용요금          0.046174 -0.004301   -0.001817   0.002632  ...
# 최근3개월무료량초과개월수     -0.024943  0.001620    0.028883  -0.033210  ...
# 3개월_ARPU          -0.015179  0.016223    0.038442  -0.001959  ...
# 최근3개월무선데이터사용량      0.002908 -0.000181   -0.005623   0.002835  ...
# 최근무선데이터사용량         0.002915 -0.000180   -0.005583   0.002815  ...
# ...                     ...       ...         ...        ...  ...
# 단말기잔여할부금액         -0.000939 -0.000177   -0.005472   0.002760  ...
# 데이터총제공량            0.002475 -0.000237   -0.007336   0.003699  ...
# 말일데이터사용량           0.002915 -0.000180   -0.005583   0.002815  ...
# 말일데이터소진율           0.002819 -0.000195   -0.006039   0.003045  ...
# 평균3개월데이터소진율        0.002851 -0.000190   -0.005888   0.002969  ...
# 타사모바일사용단말기수        0.100980 -0.001020    0.036656   0.004759  ...
# 타사추정만료단말기수         0.033662  0.000137    0.030662   0.004238  ...
# 최근3개월멤버쉽사용횟수       0.107240 -0.008544   -0.291979   0.109724  ...
# 최근6개월멤버쉽사용횟수       0.111118 -0.004402   -0.315346   0.117365  ...
# 최근1년멤버쉽사용횟수        0.113884 -0.002079   -0.328586   0.120128  ...
# 최근3개월VIP횟수         0.066874 -0.005008   -0.265751   0.126311  ...
# 최근6개월VIP초이스횟수      0.078521  0.007787   -0.269818   0.126520  ...
# 최근1년VIP초이스횟수            NaN       NaN         NaN        NaN  ...
# 최근3개월더블할인횟수        0.017783 -0.004431   -0.242811   0.097600  ...
# 최근6개월더블할인횟수        0.017678 -0.007884   -0.260287   0.104544  ...
# 최근1년베이커리횟수         0.035229  0.005392   -0.277101   0.117119  ...
# 최근3개월영화횟수               NaN       NaN         NaN        NaN  ...
# 최근1년영화관람횟수         0.049668  0.057170   -0.268178   0.121415  ...
# 최근3개월외식횟수          0.051018  0.006123   -0.157884   0.066130  ...
# 최근1년외식횟수           0.059190  0.008294   -0.228313   0.091772  ...
# 최근3개월카페사용횟수             NaN       NaN         NaN        NaN  ...
# 최근1년카페사용횟수         0.035444 -0.003574   -0.199959   0.072087  ...
# 최근3개월편의점사용횟수      -0.004067 -0.006103   -0.165247   0.066915  ...
# 최근1년편의점사용횟수       -0.006650 -0.006650   -0.184914   0.074501  ...
# 최근1년그레이드컬처횟수       0.013130 -0.002407   -0.058676   0.026553  ...
# 최근1년그레이트페스티벌횟수     0.110480 -0.001591   -0.018548   0.018998  ...
# 최근3개월지니팩사용횟수       0.004167  0.023135   -0.050133   0.027706  ...
# 최근3개월IPTV_VOD사용횟수  0.116359 -0.006822   -0.102703   0.024480  ...
# 최근3개월데이터충전횟수      -0.014945 -0.005885   -0.160484   0.073370  ...
# 최근3개월패박사용횟수        0.007672 -0.003065   -0.084469   0.040127  ...
#
#                    최근3개월카페사용횟수  최근1년카페사용횟수  최근3개월편의점사용횟수  최근1년편의점사용횟수  \
# SOP결합여부                    NaN         NaN           NaN          NaN
# 와이브로결합여부                   NaN         NaN           NaN          NaN
# PSTN회선수                    NaN   -0.038492     -0.037063    -0.032537
# 모바일회선수                     NaN    0.174255      0.146626     0.177676
# SOIP회선수                    NaN    0.020174     -0.004403    -0.006958
# 인터넷회선수                     NaN    0.036755      0.010118     0.022504
# IPTV회선수                    NaN    0.035444     -0.004067    -0.006650
# 와이브로회선수                    NaN   -0.003574     -0.006103    -0.006650
# 모바일약정전여개월수                 NaN   -0.199959     -0.165247    -0.184914
# 모바일해지후개월수                  NaN    0.072087      0.066915     0.074501
# 나이                         NaN   -0.027023     -0.032018    -0.025452
# 인터넷가입경과개월수                 NaN   -0.034942     -0.025522    -0.026549
# 인터넷만료기간개월수                 NaN   -0.038173     -0.025529    -0.030220
# 인터넷해지경과개월수                 NaN    0.011089      0.011729     0.014527
# IPTV약정만료잔여개월수              NaN   -0.036478     -0.026742    -0.027483
# IPTV_3개월_ARPU              NaN   -0.002172     -0.016411    -0.015426
# 모바일_3개월_ARPU               NaN    0.185858      0.143274     0.162632
# 인터넷_3개월_ARPU               NaN   -0.012176     -0.016606    -0.015864
# 모바일_6개월_ARPU               NaN    0.187533      0.141581     0.163521
# 인터넷_6개월_ARPU               NaN   -0.020744     -0.029204    -0.027569
# 최근3개월IPTV_사용시간             NaN    0.007174      0.016519     0.012745
# 가입후경과개월수                   NaN    0.019350      0.015179     0.018007
# 결합약정만료잔여개월수                NaN   -0.029505     -0.033293    -0.036770
# 최근월PPV사용금액                 NaN   -0.015251     -0.011373    -0.013495
# 약정잔여개월수                    NaN   -0.035724     -0.030213    -0.031965
# 전월PPV사용요금                  NaN   -0.014869     -0.010681    -0.011531
# 최근3개월무료량초과개월수              NaN    0.009417      0.019432     0.013352
# 3개월_ARPU                   NaN   -0.026568     -0.023043    -0.025787
# 최근3개월무선데이터사용량              NaN    0.000606      0.039462     0.068051
# 최근무선데이터사용량                 NaN    0.000620      0.039451     0.068069
# ...                        ...         ...           ...          ...
# 단말기잔여할부금액                  NaN   -0.001767     -0.001451    -0.001669
# 데이터총제공량                    NaN   -0.000034      0.038098     0.065178
# 말일데이터사용량                   NaN    0.000620      0.039451     0.068069
# 말일데이터소진율                   NaN    0.000461      0.039411     0.067676
# 평균3개월데이터소진율                NaN    0.000514      0.039457     0.067823
# 타사모바일사용단말기수                NaN    0.000626     -0.000758    -0.002642
# 타사추정만료단말기수                 NaN   -0.009647     -0.001181    -0.003160
# 최근3개월멤버쉽사용횟수               NaN    0.331862      0.508995     0.443522
# 최근6개월멤버쉽사용횟수               NaN    0.372428      0.524487     0.529235
# 최근1년멤버쉽사용횟수                NaN    0.383922      0.479767     0.569652
# 최근3개월VIP횟수                 NaN    0.338109      0.171190     0.178643
# 최근6개월VIP초이스횟수              NaN    0.373362      0.177191     0.197436
# 최근1년VIP초이스횟수               NaN         NaN           NaN          NaN
# 최근3개월더블할인횟수                NaN    0.306605      0.221536     0.213703
# 최근6개월더블할인횟수                NaN    0.360223      0.229633     0.233641
# 최근1년베이커리횟수                 NaN    0.217912      0.214347     0.233940
# 최근3개월영화횟수                  NaN         NaN           NaN          NaN
# 최근1년영화관람횟수                 NaN    0.159936      0.110549     0.144376
# 최근3개월외식횟수                  NaN    0.164879      0.079825     0.080315
# 최근1년외식횟수                   NaN    0.226838      0.127147     0.154110
# 최근3개월카페사용횟수                NaN         NaN           NaN          NaN
# 최근1년카페사용횟수                 NaN    1.000000      0.220435     0.248482
# 최근3개월편의점사용횟수               NaN    0.220435      1.000000     0.843456
# 최근1년편의점사용횟수                NaN    0.248482      0.843456     1.000000
# 최근1년그레이드컬처횟수               NaN    0.062660      0.037650     0.039003
# 최근1년그레이트페스티벌횟수             NaN    0.066641      0.023022     0.028713
# 최근3개월지니팩사용횟수               NaN    0.022909      0.024032     0.020541
# 최근3개월IPTV_VOD사용횟수          NaN    0.037743      0.005256     0.006958
# 최근3개월데이터충전횟수               NaN    0.074896      0.055694     0.054203
# 최근3개월패박사용횟수                NaN    0.025823      0.014314     0.016139
#
#                    최근1년그레이드컬처횟수  최근1년그레이트페스티벌횟수  최근3개월지니팩사용횟수  \
# SOP결합여부                     NaN             NaN           NaN
# 와이브로결합여부                    NaN             NaN           NaN
# PSTN회선수               -0.030337       -0.030479     -0.014293
# 모바일회선수                 0.042124        0.029680      0.045054
# SOIP회선수               -0.004351       -0.008014     -0.012564
# 인터넷회선수                 0.017123        0.070176      0.007051
# IPTV회선수                0.013130        0.110480      0.004167
# 와이브로회선수               -0.002407       -0.001591      0.023135
# 모바일약정전여개월수            -0.058676       -0.018548     -0.050133
# 모바일해지후개월수              0.026553        0.018998      0.027706
# 나이                    -0.017686       -0.012833      0.014146
# 인터넷가입경과개월수            -0.009463       -0.016343     -0.009671
# 인터넷만료기간개월수            -0.012448       -0.010107     -0.008562
# 인터넷해지경과개월수             0.003322        0.004325      0.005868
# IPTV약정만료잔여개월수         -0.010012       -0.015552     -0.010154
# IPTV_3개월_ARPU          0.009107        0.035889      0.005592
# 모바일_3개월_ARPU           0.049616        0.025621      0.066323
# 인터넷_3개월_ARPU          -0.003786        0.011318     -0.000517
# 모바일_6개월_ARPU           0.052227        0.024271      0.071158
# 인터넷_6개월_ARPU          -0.005605        0.023269      0.000035
# 최근3개월IPTV_사용시간        -0.005827        0.010606      0.012672
# 가입후경과개월수               0.011240        0.010807     -0.023688
# 결합약정만료잔여개월수           -0.007435       -0.003436      0.014656
# 최근월PPV사용금액             0.003985       -0.006708      0.005253
# 약정잔여개월수               -0.015822       -0.015461     -0.008167
# 전월PPV사용요금              0.004293       -0.006575      0.005536
# 최근3개월무료량초과개월수         -0.000240        0.001438     -0.010446
# 3개월_ARPU              -0.002228       -0.007097      0.011850
# 최근3개월무선데이터사용량         -0.000437       -0.000289     -0.000392
# 최근무선데이터사용량            -0.000434       -0.000287     -0.000389
# ...                         ...             ...           ...
# 단말기잔여할부금액             -0.000425       -0.000281     -0.000381
# 데이터총제공량               -0.000570       -0.000377     -0.000511
# 말일데이터사용량              -0.000434       -0.000287     -0.000389
# 말일데이터소진율              -0.000469       -0.000310     -0.000421
# 평균3개월데이터소진율           -0.000458       -0.000302     -0.000410
# 타사모바일사용단말기수            0.000306        0.004821     -0.002694
# 타사추정만료단말기수            -0.002898       -0.002614     -0.004817
# 최근3개월멤버쉽사용횟수           0.050761        0.032664      0.041157
# 최근6개월멤버쉽사용횟수           0.061866        0.037760      0.044980
# 최근1년멤버쉽사용횟수            0.062655        0.036856      0.036044
# 최근3개월VIP횟수             0.074135        0.104595      0.031775
# 최근6개월VIP초이스횟수          0.076636        0.116351      0.028120
# 최근1년VIP초이스횟수                NaN             NaN           NaN
# 최근3개월더블할인횟수            0.040025        0.012207      0.025000
# 최근6개월더블할인횟수            0.047973        0.026410      0.020679
# 최근1년베이커리횟수             0.036501        0.007760      0.014076
# 최근3개월영화횟수                   NaN             NaN           NaN
# 최근1년영화관람횟수             0.089306        0.057878      0.013754
# 최근3개월외식횟수              0.029494        0.040314      0.050991
# 최근1년외식횟수               0.060703        0.063072      0.056451
# 최근3개월카페사용횟수                 NaN             NaN           NaN
# 최근1년카페사용횟수             0.062660        0.066641      0.022909
# 최근3개월편의점사용횟수           0.037650        0.023022      0.024032
# 최근1년편의점사용횟수            0.039003        0.028713      0.020541
# 최근1년그레이드컬처횟수           1.000000        0.037244      0.017680
# 최근1년그레이트페스티벌횟수         0.037244        1.000000      0.014462
# 최근3개월지니팩사용횟수           0.017680        0.014462      1.000000
# 최근3개월IPTV_VOD사용횟수      0.009639       -0.000545      0.002472
# 최근3개월데이터충전횟수           0.007986        0.034208     -0.010460
# 최근3개월패박사용횟수            0.016672       -0.002162     -0.000799
#
#                    최근3개월IPTV_VOD사용횟수  최근3개월데이터충전횟수  최근3개월패박사용횟수
# SOP결합여부                          NaN           NaN          NaN
# 와이브로결합여부                         NaN           NaN          NaN
# PSTN회선수                    -0.014202     -0.058230    -0.023119
# 모바일회선수                      0.083889      0.117934     0.065811
# SOIP회선수                     0.056976     -0.014513     0.014429
# 인터넷회선수                      0.067641     -0.013906    -0.010870
# IPTV회선수                     0.116359     -0.014945     0.007672
# 와이브로회선수                    -0.006822     -0.005885    -0.003065
# 모바일약정전여개월수                 -0.102703     -0.160484    -0.084469
# 모바일해지후개월수                   0.024480      0.073370     0.040127
# 나이                         -0.027306     -0.022998    -0.007220
# 인터넷가입경과개월수                 -0.148917     -0.014612    -0.014768
# 인터넷만료기간개월수                 -0.047654     -0.015515     0.004103
# 인터넷해지경과개월수                  0.021434      0.005976    -0.019395
# IPTV약정만료잔여개월수              -0.150218     -0.013727    -0.013297
# IPTV_3개월_ARPU               0.247276     -0.023969    -0.013159
# 모바일_3개월_ARPU                0.107613      0.090479     0.042051
# 인터넷_3개월_ARPU                0.018398     -0.022948    -0.014581
# 모바일_6개월_ARPU                0.105631      0.091195     0.044969
# 인터넷_6개월_ARPU                0.034874     -0.042767    -0.026552
# 최근3개월IPTV_사용시간              0.057346      0.009432     0.000246
# 가입후경과개월수                    0.007460      0.013163     0.025466
# 결합약정만료잔여개월수                -0.026721     -0.029111    -0.007255
# 최근월PPV사용금액                  0.105115     -0.017011    -0.014802
# 약정잔여개월수                    -0.037088     -0.025414    -0.008231
# 전월PPV사용요금                   0.102587     -0.016443    -0.014414
# 최근3개월무료량초과개월수               0.019919     -0.000969     0.010434
# 3개월_ARPU                    0.076833     -0.025323    -0.027539
# 최근3개월무선데이터사용량              -0.001645     -0.001068    -0.000556
# 최근무선데이터사용량                 -0.001633     -0.001061    -0.000552
# ...                              ...           ...          ...
# 단말기잔여할부금액                  -0.001601     -0.001040    -0.000542
# 데이터총제공량                    -0.002146     -0.001394    -0.000726
# 말일데이터사용량                   -0.001633     -0.001061    -0.000552
# 말일데이터소진율                   -0.001766     -0.001147    -0.000598
# 평균3개월데이터소진율                -0.001722     -0.001119    -0.000583
# 타사모바일사용단말기수                 0.000107     -0.017743     0.010082
# 타사추정만료단말기수                 -0.004939     -0.013165     0.012596
# 최근3개월멤버쉽사용횟수                0.771255      0.142008     0.052281
# 최근6개월멤버쉽사용횟수                0.679983      0.119351     0.038316
# 최근1년멤버쉽사용횟수                 0.584386      0.099540     0.031088
# 최근3개월VIP횟수                  0.031142      0.056113     0.073840
# 최근6개월VIP초이스횟수               0.030131      0.055215     0.057653
# 최근1년VIP초이스횟수                     NaN           NaN          NaN
# 최근3개월더블할인횟수                 0.039009      0.104751     0.093833
# 최근6개월더블할인횟수                 0.043501      0.096486     0.088104
# 최근1년베이커리횟수                  0.052580      0.075093     0.031923
# 최근3개월영화횟수                        NaN           NaN          NaN
# 최근1년영화관람횟수                  0.028431      0.034934     0.042289
# 최근3개월외식횟수                   0.039062      0.047492     0.020627
# 최근1년외식횟수                    0.058517      0.054743     0.028670
# 최근3개월카페사용횟수                      NaN           NaN          NaN
# 최근1년카페사용횟수                  0.037743      0.074896     0.025823
# 최근3개월편의점사용횟수                0.005256      0.055694     0.014314
# 최근1년편의점사용횟수                 0.006958      0.054203     0.016139
# 최근1년그레이드컬처횟수                0.009639      0.007986     0.016672
# 최근1년그레이트페스티벌횟수             -0.000545      0.034208    -0.002162
# 최근3개월지니팩사용횟수                0.002472     -0.010460    -0.000799
# 최근3개월IPTV_VOD사용횟수           1.000000     -0.001047    -0.001847
# 최근3개월데이터충전횟수               -0.001047      1.000000     0.099292
# 최근3개월패박사용횟수                -0.001847      0.099292     1.000000
#
# [71 rows x 71 columns]
