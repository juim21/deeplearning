# %%
import pandas as pd

df_pre = pd.read_csv('../dataset/wine.csv',header=None)
df = df_pre.sample(frac=1)

# %%
print(df.head(5))

# %%
# 각 컬럼의 의미
# 0: 주석산 농도, 1: 아세트산 농도, 2: 구연산 농도, 3: 잔류 당분 농도
# 4: 염화나투륨 농도, 5: 유리 아황산 농도, 6: 총 아황산 농도
# 7: 밀도, 8: pH, 9: 황산칼륨농도
# 10: 알콜 도수, 11: 와인의 맛(0~10등급), 12: class(1: 레드와인, 0: 화이트 와인)

print(df.info())

# %%
dataset = df.values
column = df.columns
X = dataset[:,0:len(column)-1]
Y = dataset[:,len(column)-1]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy
import tensorflow as tf
import matplotlib.pyplot as plt
import os
# Out:
# Using TensorFlow backend.

# %%
#seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('../dataset/wine.csv',header=None)
df =df_pre.sample(frac=1)
dataset = df.values
column = df.columns

X = dataset[:,0:len(column)-1]
Y = dataset[:,len(column)-1]

# %%
#모델 설정
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#모델 컴파일
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

# %%
# 모델 저장 폴더 설정
MODEL_DIR = './model'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

#모델 저장 조건 설정
modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# %%
#모델 실행
model.fit(X,Y,validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: val_loss improved from inf to 0.10926, saving model to ./model/01-0.1093.hdf5
#
# Epoch 00002: val_loss improved from 0.10926 to 0.10790, saving model to ./model/02-0.1079.hdf5
#
# Epoch 00003: val_loss improved from 0.10790 to 0.10259, saving model to ./model/03-0.1026.hdf5
#
# Epoch 00004: val_loss improved from 0.10259 to 0.10081, saving model to ./model/04-0.1008.hdf5
#
# Epoch 00005: val_loss did not improve from 0.10081
#
# Epoch 00006: val_loss improved from 0.10081 to 0.09845, saving model to ./model/06-0.0985.hdf5
#
# Epoch 00007: val_loss did not improve from 0.09845
#
# Epoch 00008: val_loss improved from 0.09845 to 0.09215, saving model to ./model/08-0.0922.hdf5
#
# Epoch 00009: val_loss improved from 0.09215 to 0.08748, saving model to ./model/09-0.0875.hdf5
#
# Epoch 00010: val_loss did not improve from 0.08748
#
# Epoch 00011: val_loss improved from 0.08748 to 0.08561, saving model to ./model/11-0.0856.hdf5
#
# ...

# %%
#결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X,Y)[1]))
# Out:
# 6497/6497 [==============================] - 0s 57us/step
#
#  Accuracy: 0.9874

# %%
#그래프 표현
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import
