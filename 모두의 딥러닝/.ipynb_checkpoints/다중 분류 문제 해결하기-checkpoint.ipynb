# %%
#다중 분류 문제 해결
import pandas as pd
df = pd.read_csv('../dataset/iris.csv',names=["sepal_length","sepal_width","petal_length","petal_width","species"])
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df,hue='species');
plt.show()

# %%
dataset=df.values
X = dataset[:,0:4].astype(float)
Y_obj = dataset[:,4]

# %%
from sklearn.preprocessing import LabelEncoder
#문자열을 숫자로 바꿔 주려면 클래스 이름을 숫자 형태로 바꿔야 함
#이를 지원하는게 sklearn에 LabelEncoder()임

# %%
e=LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)
#이렇게 하면 array(['Iris-setosa','Iris-versicolor','Iris-virginica'])가 array([1,2,3])으로 바뀜

# %%
#활성화 함수를 적용하려면 Y 값이 숫자 0과 1로 이루어져 있어야 함
#이 조건 만족을 위해서 keras.util의 np_utils.categorical() 함수 사용해야함
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense

Y_encoded = np_utils.to_categorical(Y)
#이렇게 하면 array([1,2,3])이 array([[1.,0,0],[0,1.,0],[0,0,1.]] 로 바뀜
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Dense(16, input_dim=4,activation='relu'))
model.add(Dense(3,activation='softmax'))

# %%
#아이리스 품종 예측
from keras.models import Sequential
from keras.layers.core import Dense
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy
import tensorflow as tf

# %%
#seed값 설정
seed = 0
numpy.random.seed(seed)
tf.set_random_seed(seed)

# %%
#데이터 입력
df = pd.read_csv('../dataset/iris.csv', names = ["sepal_length","sepal_width","petal_length", "petal_width","species"])

# %%
# 그래프로 확인
sns.pairplot(df, hue="species")
plt.show()

# %%
#데이터 분류
dataset=df.values
X = dataset[:,0:4].astype(float)
Y_obj = dataset[:,4]

# %%
#문자열을 숫자로 변환
e=LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)
Y_encoded = np_utils.to_categorical(Y)

# %%
#모델의 설정
model = Sequential()
model.add(Dense(16,input_dim=4,activation='relu'))

# %%
model.add(Dense(3,activation='softmax'))

# %%
#모델 컴파일
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#모델 실행
model.fit(X,Y_encoded,epochs=50, batch_size=1)
# Out:
# Epoch 1/50
# 150/150 [==============================] - 19s 123ms/step - loss: 1.6293 - acc: 0.3267
# Epoch 2/50
# 150/150 [==============================] - 0s 3ms/step - loss: 1.1395 - acc: 0.4933
# Epoch 3/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.9397 - acc: 0.4600
# Epoch 4/50
# 150/150 [==============================] - 1s 3ms/step - loss: 0.7885 - acc: 0.7467
# Epoch 5/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.6659 - acc: 0.7333
# Epoch 6/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.5630 - acc: 0.8867
# Epoch 7/50
# 150/150 [==============================] - 1s 3ms/step - loss: 0.5076 - acc: 0.8267
# Epoch 8/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.4554 - acc: 0.9333
# Epoch 9/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.4284 - acc: 0.8867
# Epoch 10/50
# 150/150 [==============================] - 0s 3ms/step - loss: 0.4067 - acc: 0.8867
# ...

# %%
#결과출력
print("\n Accuracy: %.4f"% (model.evaluate(X,Y_encoded)[1]))
# Out:
# 150/150 [==============================] - 0s 1ms/step
#
#  Accuracy: 0.9733
