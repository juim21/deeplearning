# %%
import pandas as pd

# %%
dataset = pd.read_csv("dataset/cam_dataset_all.csv", encoding='UTF8')

# %%
dataset.shape
# Out:
# (32060, 144)

# %%
products = pd.DataFrame({'category': ['Cleaning', 'Cleaning', 'Entertainment', 'Entertainment', 'Tech', 'Tech'],
        'store': ['Walmart', 'Dia', 'Walmart', 'Fnac', 'Dia','Walmart'],
        'price':[11.42, 23.50, 19.99, 15.95, 55.75, 111.55],
        'testscore': [4, 3, 5, 7, 5, 8]})

print(products)

# %%
pivot_products = products.pivot(index='category', columns='store', values='price')
print(pivot_products)

# %%
dataset.dtypes

# %%
df = dataset.select_dtypes('object')

# %%
print(df)
# Out:
# (      인터넷결합여부 IPTV결합여무 PSTN결합여부 모바일결합여부 모바일사용여부 스마트폰사영여부 아동부가서비스가입여부 올레클럽가입여부  \
# 0           Y        Y        Y       Y       Y        Y           N        Y
# 1           Y        Y        Y       Y       N        N           N        Y
# 2           Y        Y        N       Y       Y        Y           N        Y
# 3           N        N        N       N       N        N           N        N
# 4           N        N        N       N       N        N           N        N
# 5           N        N        N       N       N        N           N        N
# 6           N        N        N       N       Y        Y           N        Y
# 7           N        N        N       N       N        N           N        Y
# 8           N        N        N       N       N        N           N        Y
# 9           Y        Y        N       Y       N        N           Y        Y
# 10          N        N        Y       N       Y        Y           N        Y
# 11          N        N        Y       N       Y        Y           N        Y
# 12          N        N        N       N       N        N           N        Y
# 13          N        N        N       N       N        N           N        Y
# 14          N        N        N       N       N        N           N        Y
# 15          N        N        N       N       Y        Y           N        Y
# 16          N        N        N       N       N        N           N        Y
# 17          Y        Y        N       N       N        N           N        Y
# 18          Y        Y        Y       Y       Y        Y           N        Y
# 19          N        N        Y       Y       Y        Y           N        Y
# 20          Y        Y        Y       Y       Y        Y           N        Y
# 21          Y        N        Y       N       N        N           N        N
# 22          Y        Y        Y       Y       Y        Y           N        Y
# 23          N        N        N       N       Y        Y           N        N
# 24          Y        Y        Y       N       Y        N           N        Y
# 25          N        N        N       N       N        N           N        N
# 26          Y        Y        Y       Y       Y        Y           N        Y
# 27          Y        N        Y       Y       Y        Y           N        Y
# 28          Y        Y        N       Y       Y        Y           N        Y
# 29          Y        Y        Y       Y       Y        Y           N        Y
# ...       ...      ...      ...     ...     ...      ...         ...      ...
# 32030       Y        Y        Y       Y       N        N           N        Y
# 32031       Y        Y        Y       Y       N        N           N        Y
# 32032       Y        Y        Y       N       N        N           N        Y
# 32033       Y        Y        Y       N       N        N           N        Y
# 32034       Y        Y        Y       N       N        N           N        Y
# 32035       Y        Y        Y       Y       N        N           N        N
# 32036       N        N        Y       N       N        N           N        N
# 32037       N        N        Y       N       N        N           N        N
# 32038       Y        Y        N       N       N        N           N        Y
# 32039       Y        Y        N       N       N        N           N        Y
# 32040       Y        Y        N       Y       Y        Y           N        Y
# 32041       Y        Y        N       Y       Y        Y           N        Y
# 32042       Y        Y        N       N       N        N           N        Y
# 32043       Y        Y        Y       N       Y        Y           N        N
# 32044       Y        Y        Y       N       Y        Y           N        N
# 32045       Y        Y        Y       N       Y        Y           N        N
# 32046       Y        Y        N       N       N        N           N        Y
# 32047       Y        Y        Y       N       Y        Y           N        N
# 32048       Y        Y        Y       N       N        N           N        Y
# 32049       Y        Y        Y       N       Y        Y           N        N
# 32050       Y        Y        N       N       N        N           N        Y
# 32051       Y        Y        N       Y       Y        Y           N        Y
# 32052       Y        Y        N       Y       Y        Y           N        Y
# 32053       Y        Y        N       Y       Y        Y           N        Y
# 32054       Y        Y        N       Y       Y        Y           N        Y
# 32055       Y        N        Y       Y       Y        Y           N        N
# 32056       Y        N        Y       Y       Y        Y           N        Y
# 32057       Y        Y        Y       Y       Y        Y           N        Y
# 32058       Y        Y        Y       Y       Y        Y           N        Y
# 32059       Y        N        Y       Y       Y        Y           N        Y
#
#       인터넷가입여부 SOIP사용여부  ... TV추정사업자ID 올래클럽가입상태 스폰서할인유형 판매유형 사용유형       납무방법  \
# 0           Y        Y  ...        KT    10011       _    _   일반  은행계좌 자동이체
# 1           Y        N  ...        KT    10011       _    _   일반       신용카드
# 2           Y        N  ...         _    10011       _    _   일반       신용카드
# 3           Y        N  ...         _        _       _    _   일반  은행계좌 자동이체
# 4           N        N  ...         _        _       _    _  주택용  은행계좌 자동이체
# 5           N        N  ...         _        _       _    _  주택용  은행계좌 자동이체
# 6           N        N  ...         _        _       _    _  주택용       신용카드
# 7           N        N  ...         _    10011       _    _  주택용       신용카드
# 8           N        N  ...         _    10011       _    _  업무용  은행계좌 자동이체
# 9           Y        Y  ...         _    10011       _    _  주택용       신용카드
# 10          N        Y  ...         _    10011       _    _  주택용       신용카드
# 11          N        Y  ...         _    10011       _    _  주택용       신용카드
# 12          N        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 13          N        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 14          N        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 15          N        N  ...         _    10011       _    _  주택용       신용카드
# 16          N        Y  ...         _    10011       _    _  주택용       신용카드
# 17          Y        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 18          Y        N  ...         _    10011       _    _  주택용         지로
# 19          N        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 20          Y        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 21          Y        N  ...         _        _       _    _  주택용  은행계좌 자동이체
# 22          Y        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 23          Y        N  ...         _        _       _    _  업무용         지로
# 24          Y        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 25          N        N  ...         _    10012       _    _  주택용       신용카드
# 26          Y        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 27          Y        N  ...         _    10011       _    _  업무용         지로
# 28          N        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 29          N        N  ...         _    10011       _    _  주택용         지로
# ...       ...      ...  ...       ...      ...     ...  ...  ...        ...
# 32030       Y        Y  ...         _    10011       _    _  주택용       신용카드
# 32031       Y        Y  ...        KT    10011       _    _   일반       신용카드
# 32032       Y        N  ...        KT    10011       _    _   일반  은행계좌 자동이체
# 32033       Y        N  ...        KT    10011       _    _   일반  은행계좌 자동이체
# 32034       Y        N  ...         _    10011       _    _  주택용  은행계좌 자동이체
# 32035       Y        N  ...         _        _       _    _   일반         지로
# 32036       Y        Y  ...         _        _       _    _  주택용         지로
# 32037       Y        Y  ...         _        _       _    _  주택용         지로
# 32038       Y        N  ...        KT    10011       _    _   일반       신용카드
# 32039       Y        N  ...        KT    10011       _    _   일반       신용카드
# 32040       Y        N  ...        KT    10011       _    _   일반       신용카드
# 32041       Y        N  ...        KT    10011       _    _   일반       신용카드
# 32042       Y        Y  ...        KT    10011       _    _   일반       신용카드
# 32043       Y        N  ...        KT        _       _    _   일반  은행계좌 자동이체
# 32044       Y        N  ...         _        _       _    _  업무용  은행계좌 자동이체
# 32045       Y        N  ...        KT        _       _    _   일반  은행계좌 자동이체
# 32046       Y        Y  ...        KT    10011       _    _   일반       신용카드
# 32047       Y        N  ...        KT        _       _    _   일반  은행계좌 자동이체
# 32048       Y        N  ...        KT    10011       _    _   일반       신용카드
# 32049       Y        N  ...         _        _       _    _  업무용  은행계좌 자동이체
# 32050       Y        Y  ...         _    10011       _    _  주택용       신용카드
# 32051       Y        N  ...        KT    10011       _    _   일반       신용카드
# 32052       Y        N  ...        KT    10011       _    _   일반       신용카드
# 32053       Y        Y  ...        KT    10011       _    _   일반         지로
# 32054       Y        Y  ...        KT    10011       _    _   일반         지로
# 32055       Y        N  ...         _        _       _    _   일반  은행계좌 자동이체
# 32056       Y        N  ...         _    10011       _    _  업무용       신용카드
# 32057       Y        N  ...        KT    10011       _    _   일반  은행계좌 자동이체
# 32058       Y        N  ...         _    10011       _    _  주택용     지로자동이체
# 32059       Y        N  ...         _    10011       _    _   일반       신용카드
#
#            반응1                            반응2     반응3           반응4
# 0        SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 1        SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 2        SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 3        고객측사유                       고객측사유_기타      KT            해지
# 4        SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 5        SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 6       회선품질불만                          품질_기타     미사용            해지
# 7          불필요                      사용저조/환경변화     미사용            해지
# 8        고객측사유                       가족/지인등권유      KT            해지
# 9        고객측사유                         고객기기문제     미사용            해지
# 10       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 11       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 12       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 13       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 14       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 15       SR불필요  6eZsredsxz5trzdftrfdxzgftfdx6    혜택제공  지속사용(고객혜택제공)
# 16       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 17       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 18         불필요                          합가/합병      LG            해지
# 19       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 20       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 21       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 22       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 23       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 24       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 25       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 26       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 27       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 28       SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 29         불필요                           무선사용     미사용            해지
# ...        ...                            ...     ...           ...
# 32030     해지징후                           혜택문의    혜택문의        지속(정책)
# 32031     해지징후                           혜택문의    혜택문의        지속(정책)
# 32032      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32033      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32034      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32035    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32036      불필요                           회선줄임     미사용            해지
# 32037      불필요                      사용저조/환경변화     미사용        지속(정책)
# 32038     무선영향                     탐색거절/사유확인불      LG        지속(정책)
# 32039     무선영향                     탐색거절/사유확인불      LG        지속(정책)
# 32040  요금/혜택불만                       신규혜택/사은품     KT.        지속(정책)
# 32041  요금/혜택불만                       신규혜택/사은품     KT.        지속(정책)
# 32042  요금/혜택불만                        유선_장기혜택  통신사확인불        지속(혜택)
# 32043     해지징후                           혜택문의    혜택문의        지속(혜택)
# 32044     해지징후                           혜택문의    혜택문의        지속(혜택)
# 32045     해지징후                           혜택문의    혜택문의        지속(혜택)
# 32046  요금/혜택불만                        유선_장기혜택  통신사확인불        지속(혜택)
# 32047    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32048     해지징후                           혜택문의    혜택문의        지속(정책)
# 32049    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32050  요금/혜택불만                        유선_장기혜택  통신사확인불        지속(정책)
# 32051      불필요                      사용저조/환경변화  통신사확인불        지속(정책)
# 32052      불필요                      사용저조/환경변화  통신사확인불        지속(정책)
# 32053     해지징후                           혜택문의    혜택문의        지속(정책)
# 32054     해지징후                           혜택문의    혜택문의        지속(정책)
# 32055      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32056      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32057    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32058  요금/혜택불만                            출동비     미사용        지속(혜택)
# 32059     해지징후                           혜택문의    혜택문의        지속(혜택)
#
# [32060 rows x 72 columns],               고객번호 인터넷결합여부 IPTV결합여무 PSTN결합여부 모바일결합여부 모바일사용여부 스마트폰사영여부  \
# 0      87HL036LE93       Y        Y        Y       Y       Y        Y
# 1      8MYL79EHX9Z       Y        Y        Y       Y       N        N
# 2      7QLKZUQHXHJ       Y        Y        N       Y       Y        Y
# 3      BE1L6Y4H2NG       N        N        N       N       N        N
# 4      9KWL716JWKU       N        N        N       N       N        N
# 5      9KWL716JWKU       N        N        N       N       N        N
# 6      9YNKZH0K3HS       N        N        N       N       Y        Y
# 7      AFHL004LCNQ       N        N        N       N       N        N
# 8      AEEL76LIMR4       N        N        N       N       N        N
# 9      DSUL7HCHY75       Y        Y        N       Y       N        N
# 10     EXNKZS4K14I       N        N        Y       N       Y        Y
# 11     EXNKZS4K14I       N        N        Y       N       Y        Y
# 12     9FMKZMDKPSO       N        N        N       N       N        N
# 13     9FMKZMDKPSO       N        N        N       N       N        N
# 14     9FMKZMDKPSO       N        N        N       N       N        N
# 15     8ONL73OLFCV       N        N        N       N       Y        Y
# 16     EUUKZMLILQF       N        N        N       N       N        N
# 17     ERCKZ88GTIS       Y        Y        N       N       N        N
# 18     CRUL7KIKVLV       Y        Y        Y       Y       Y        Y
# 19     CQQKZMMGGHQ       N        N        Y       Y       Y        Y
# 20     ABPL7HEJ9VJ       Y        Y        Y       Y       Y        Y
# 21     C8JL79JHGD8       Y        N        Y       N       N        N
# 22     ABPL7HEJ9VJ       Y        Y        Y       Y       Y        Y
# 23     F84L7BSJ00F       N        N        N       N       Y        Y
# 24     DAYL7HRJE3R       Y        Y        Y       N       Y        N
# 25     EDXL78XKBRH       N        N        N       N       N        N
# 26     CYXL7N2H0PX       Y        Y        Y       Y       Y        Y
# 27     D0HL7F0HR9Q       Y        N        Y       Y       Y        Y
# 28     8FFKZUGJFIU       Y        Y        N       Y       Y        Y
# 29     BS6L7Q6GLKL       Y        Y        Y       Y       Y        Y
# ...            ...     ...      ...      ...     ...     ...      ...
# 32030  8CUKZUSHK4V       Y        Y        Y       Y       N        N
# 32031  8CUKZUSHK4V       Y        Y        Y       Y       N        N
# 32032  C0E4DOAOCTC       Y        Y        Y       N       N        N
# 32033  C0E4DOAOCTC       Y        Y        Y       N       N        N
# 32034  C0E4DOAOCTC       Y        Y        Y       N       N        N
# 32035  9MRL7Q7KO4T       Y        Y        Y       Y       N        N
# 32036  DQ0KZXMIMNQ       N        N        Y       N       N        N
# 32037  DQ0KZXMIMNQ       N        N        Y       N       N        N
# 32038  9A8L7N7K1CH       Y        Y        N       N       N        N
# 32039  9A8L7N7K1CH       Y        Y        N       N       N        N
# 32040  7Y1L7NEIZ06       Y        Y        N       Y       Y        Y
# 32041  7Y1L7NEIZ06       Y        Y        N       Y       Y        Y
# 32042  F02KZUOKRA9       Y        Y        N       N       N        N
# 32043  0CGWCI9J1Y4       Y        Y        Y       N       Y        Y
# 32044  0CGWCI9J1Y4       Y        Y        Y       N       Y        Y
# 32045  0CGWCI9J1Y4       Y        Y        Y       N       Y        Y
# 32046  F02KZUOKRA9       Y        Y        N       N       N        N
# 32047  0CGWCI9J1Y4       Y        Y        Y       N       Y        Y
# 32048  BFFL76CHRQC       Y        Y        Y       N       N        N
# 32049  0CGWCI9J1Y4       Y        Y        Y       N       Y        Y
# 32050  F02KZUOKRA9       Y        Y        N       N       N        N
# 32051  AG1L7KRJI02       Y        Y        N       Y       Y        Y
# 32052  AG1L7KRJI02       Y        Y        N       Y       Y        Y
# 32053  0BHOCHOH995       Y        Y        N       Y       Y        Y
# 32054  0BHOCHOH995       Y        Y        N       Y       Y        Y
# 32055  9BBKZGFKAWU       Y        N        Y       Y       Y        Y
# 32056  8TZL7F1HJ5R       Y        N        Y       Y       Y        Y
# 32057  DTXL7K5HKAH       Y        Y        Y       Y       Y        Y
# 32058  989L7KNK1G0       Y        Y        Y       Y       Y        Y
# 32059  E6QKZXIH341       Y        N        Y       Y       Y        Y
#
#       아동부가서비스가입여부 올레클럽가입여부 인터넷가입여부  ... TV추정사업자ID 올래클럽가입상태 스폰서할인유형 판매유형 사용유형  \
# 0               N        Y       Y  ...        KT    10011       _    _   일반
# 1               N        Y       Y  ...        KT    10011       _    _   일반
# 2               N        Y       Y  ...         _    10011       _    _   일반
# 3               N        N       Y  ...         _        _       _    _   일반
# 4               N        N       N  ...         _        _       _    _  주택용
# 5               N        N       N  ...         _        _       _    _  주택용
# 6               N        Y       N  ...         _        _       _    _  주택용
# 7               N        Y       N  ...         _    10011       _    _  주택용
# 8               N        Y       N  ...         _    10011       _    _  업무용
# 9               Y        Y       Y  ...         _    10011       _    _  주택용
# 10              N        Y       N  ...         _    10011       _    _  주택용
# 11              N        Y       N  ...         _    10011       _    _  주택용
# 12              N        Y       N  ...         _    10011       _    _  주택용
# 13              N        Y       N  ...         _    10011       _    _  주택용
# 14              N        Y       N  ...         _    10011       _    _  주택용
# 15              N        Y       N  ...         _    10011       _    _  주택용
# 16              N        Y       N  ...         _    10011       _    _  주택용
# 17              N        Y       Y  ...         _    10011       _    _  주택용
# 18              N        Y       Y  ...         _    10011       _    _  주택용
# 19              N        Y       N  ...         _    10011       _    _  주택용
# 20              N        Y       Y  ...         _    10011       _    _  주택용
# 21              N        N       Y  ...         _        _       _    _  주택용
# 22              N        Y       Y  ...         _    10011       _    _  주택용
# 23              N        N       Y  ...         _        _       _    _  업무용
# 24              N        Y       Y  ...         _    10011       _    _  주택용
# 25              N        N       N  ...         _    10012       _    _  주택용
# 26              N        Y       Y  ...         _    10011       _    _  주택용
# 27              N        Y       Y  ...         _    10011       _    _  업무용
# 28              N        Y       N  ...         _    10011       _    _  주택용
# 29              N        Y       N  ...         _    10011       _    _  주택용
# ...           ...      ...     ...  ...       ...      ...     ...  ...  ...
# 32030           N        Y       Y  ...         _    10011       _    _  주택용
# 32031           N        Y       Y  ...        KT    10011       _    _   일반
# 32032           N        Y       Y  ...        KT    10011       _    _   일반
# 32033           N        Y       Y  ...        KT    10011       _    _   일반
# 32034           N        Y       Y  ...         _    10011       _    _  주택용
# 32035           N        N       Y  ...         _        _       _    _   일반
# 32036           N        N       Y  ...         _        _       _    _  주택용
# 32037           N        N       Y  ...         _        _       _    _  주택용
# 32038           N        Y       Y  ...        KT    10011       _    _   일반
# 32039           N        Y       Y  ...        KT    10011       _    _   일반
# 32040           N        Y       Y  ...        KT    10011       _    _   일반
# 32041           N        Y       Y  ...        KT    10011       _    _   일반
# 32042           N        Y       Y  ...        KT    10011       _    _   일반
# 32043           N        N       Y  ...        KT        _       _    _   일반
# 32044           N        N       Y  ...         _        _       _    _  업무용
# 32045           N        N       Y  ...        KT        _       _    _   일반
# 32046           N        Y       Y  ...        KT    10011       _    _   일반
# 32047           N        N       Y  ...        KT        _       _    _   일반
# 32048           N        Y       Y  ...        KT    10011       _    _   일반
# 32049           N        N       Y  ...         _        _       _    _  업무용
# 32050           N        Y       Y  ...         _    10011       _    _  주택용
# 32051           N        Y       Y  ...        KT    10011       _    _   일반
# 32052           N        Y       Y  ...        KT    10011       _    _   일반
# 32053           N        Y       Y  ...        KT    10011       _    _   일반
# 32054           N        Y       Y  ...        KT    10011       _    _   일반
# 32055           N        N       Y  ...         _        _       _    _   일반
# 32056           N        Y       Y  ...         _    10011       _    _  업무용
# 32057           N        Y       Y  ...        KT    10011       _    _   일반
# 32058           N        Y       Y  ...         _    10011       _    _  주택용
# 32059           N        Y       Y  ...         _    10011       _    _   일반
#
#             납무방법      반응1                            반응2     반응3           반응4
# 0      은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 1           신용카드    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 2           신용카드    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 3      은행계좌 자동이체    고객측사유                       고객측사유_기타      KT            해지
# 4      은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 5      은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 6           신용카드   회선품질불만                          품질_기타     미사용            해지
# 7           신용카드      불필요                      사용저조/환경변화     미사용            해지
# 8      은행계좌 자동이체    고객측사유                       가족/지인등권유      KT            해지
# 9           신용카드    고객측사유                         고객기기문제     미사용            해지
# 10          신용카드    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 11          신용카드    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 12     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 13     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 14     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 15          신용카드    SR불필요  6eZsredsxz5trzdftrfdxzgftfdx6    혜택제공  지속사용(고객혜택제공)
# 16          신용카드    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 17     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 18            지로      불필요                          합가/합병      LG            해지
# 19     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 20     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 21     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 22     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 23            지로    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 24     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 25          신용카드    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 26     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 27            지로    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 28     은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 29            지로      불필요                           무선사용     미사용            해지
# ...          ...      ...                            ...     ...           ...
# 32030       신용카드     해지징후                           혜택문의    혜택문의        지속(정책)
# 32031       신용카드     해지징후                           혜택문의    혜택문의        지속(정책)
# 32032  은행계좌 자동이체      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32033  은행계좌 자동이체      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32034  은행계좌 자동이체      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32035         지로    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32036         지로      불필요                           회선줄임     미사용            해지
# 32037         지로      불필요                      사용저조/환경변화     미사용        지속(정책)
# 32038       신용카드     무선영향                     탐색거절/사유확인불      LG        지속(정책)
# 32039       신용카드     무선영향                     탐색거절/사유확인불      LG        지속(정책)
# 32040       신용카드  요금/혜택불만                       신규혜택/사은품     KT.        지속(정책)
# 32041       신용카드  요금/혜택불만                       신규혜택/사은품     KT.        지속(정책)
# 32042       신용카드  요금/혜택불만                        유선_장기혜택  통신사확인불        지속(혜택)
# 32043  은행계좌 자동이체     해지징후                           혜택문의    혜택문의        지속(혜택)
# 32044  은행계좌 자동이체     해지징후                           혜택문의    혜택문의        지속(혜택)
# 32045  은행계좌 자동이체     해지징후                           혜택문의    혜택문의        지속(혜택)
# 32046       신용카드  요금/혜택불만                        유선_장기혜택  통신사확인불        지속(혜택)
# 32047  은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32048       신용카드     해지징후                           혜택문의    혜택문의        지속(정책)
# 32049  은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32050       신용카드  요금/혜택불만                        유선_장기혜택  통신사확인불        지속(정책)
# 32051       신용카드      불필요                      사용저조/환경변화  통신사확인불        지속(정책)
# 32052       신용카드      불필요                      사용저조/환경변화  통신사확인불        지속(정책)
# 32053         지로     해지징후                           혜택문의    혜택문의        지속(정책)
# 32054         지로     해지징후                           혜택문의    혜택문의        지속(정책)
# 32055  은행계좌 자동이체      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32056       신용카드      불필요                    폐업/철수/퇴사/출장     미사용            해지
# 32057  은행계좌 자동이체    SR불필요                          SR미발행    혜택제공  지속사용(고객혜택제공)
# 32058     지로자동이체  요금/혜택불만                            출동비     미사용        지속(혜택)
# 32059       신용카드     해지징후                           혜택문의    혜택문의        지속(혜택)
#
# [32060 rows x 72 columns])

# %%
df=df.drop(columns=['고객번호']), df.drop(columns=['신규가입일자'])

# %%
resp_success = ['지속(정책)', '지속사용(고객혜택제공)', '지속(혜택)']

# %%
def resp_Yn(resp):
    if resp in resp_success:
        return 1
    else:
        return 0

# %%
df = df.add()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-57909d2e9da9> in <module>
# ----> 1 pd(__help__)
#
# NameError: name '__help__' is not defined
